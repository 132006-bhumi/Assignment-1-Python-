# %% [markdown]
# Theory Questions Assignment 2

# %% [markdown]
# Q1. What are data structures, and why are they important ?
#
# Answer:- Data structure are a way to organize , store , process and retrive data in a specific format.Data Structure is popular because it makes code more efficient and make it easy to understand.

# %% [markdown]
# Q2. Explain the difference between mutable and immutable data types with examples ?
#
# Answer:- Mutuable data types can be changed after creation,whereas immutable datatype cannot be changed after creation.we can add , remove , or modify the contents of a mutuable data type. like (List and Dictonaries) can be changed after creation and (strings , tuples) can not be alterd once defined.

# %% [markdown]
# Q3. What are the main differences between lists and tuples in Python ?
#
# Answer:- Tuple is immutable and list is mutuable .Tuple can't be changed after it's creation.List can be changed after it's creation.

# %% [markdown]
# Q4. Describe how dictionaries store data ?
#
# Answer:- Dictionaries are used to store data key:value pair .Dictionaries are stored data in form of ordered , changeable and do not allow duplicate.Dictionaries are mutuable.

# %% [markdown]
# Q5. Why might you use a set instead of a list in Python ?
#
# Answer:- sets are used when want to unique collection of element and perform fast membership checks.sets automatically remove duplicate value, making them ideal for operation that involve finding unique items or performing mathematical set operations.

# %% [markdown]
# Q6. what is a string in python ? and how it's different from a list ?
#
# Answer: String is a immutalbe sequence of characters between single or double quotes.List is mutuable sequence of any datatype , where each datatype could be anything.(like int,float,string,boolean)while both support indexing ,slicing .string can not be changed after it is created. but list can be changed after creation.

# %% [markdown]
# Q7. How do tuple ensure data Integrity in python ?
#
# Answer: Tuple is immutuable it's content can't be changed throughout their lifecyle.Data can't be changed once it's created .This charactristics leverages the Integrity of tuple in python.

# %% [markdown]
# Q8. what is hash table and how does it relate to dictionaries in python?
#
# Answer: Hash talbe is a data structrure allows you to store data in key:value pairs.In a hash table, the key of every key-value pair must be hashable, because the pairs stored are indexed by using the hash of their keys.

# %% [markdown]
# Q9. Can lists contain different data types in python?
#
# Answer: It's really list can contain different data types in python, A list can contain different data type like string , float , boolean data type.

# %% [markdown]
# Q10. xplain why string are immutale in python?
#
# Answer: String are immutalbe in python to enhance performance and security.since each string operation create a new object,it prevent unintened modifications,which improve realiablity of code.

# %% [markdown]
# Q11. What advantages do dictionaries offer over lists for certain task?
#
# Answer: Dictionaries are ideal for tasks for data-mapping, quick lookup,key-value association.and list is ideal sequencial processing , ordered collection where the order of elements matters.

# %% [markdown]
# Q12. Describe the scenario where using tuple would be preferalbe over a list ?
#
# Answer: Tuple would be preferable if you need an immutable collection where the element won't be changed after it created.Tuple are generally faster and more memory efficient than list.

# %% [markdown]
# Q13. How do set handle duplicate values in python?
#
# Answer: Sets remove automatically duplicate in pyhton.ensuring that each element is unique. This behavoiur is useful for operation where only distinct items are required , such as removing duplicate from a list.

# %% [markdown]
# Q14. How does the "In" keyword work differently for lists and dictionaries?
#
# Answer: For list , the "in" keyword checks if a value exists within the list by scanning each element.For dictionary it check if a key exists directly,providing faster lookup times due to the hash based structure of dictionary.

# %% [markdown]
# Q15. Can you modify the element of a tuple? Explain why or why not?
#
# Answer: Tuples element can't be changed if it is created . we can not add, remove element in tuple because it's immuable .

# %% [markdown]
# Q16. What is nested dictionary , and give an example of its use case?
#
# Answer: nested dictionary,is a dicionary inside dictionary .It is a collection of dictionaries into a single dictionary .just like
#
# people = {1:{'name':"ajay",'age':30}, 2:{'name':"falguni",'age':40}}

# %% [markdown]
# Q17. Describe the time complexity of accessing elements in a dictionary ?
#
# Answer: The time complexity of accessing elements in dictionary o(1).The time taken to retrieve an element from a dictionary is constant.

# %% [markdown]
# Q18. In what situations are lists preferred over dictionary ?
#
# Answer: If we need ordered collection,like sequence of user action list is used.List allow duplicate value.In dictionary used in quick look-up and used in situation username to userdata.does not allow duplicate key but allow duplicate value.

# %% [markdown]
# Q19. Why are dictionaries considered unordered , and how does that affect data retrival?
#
# Answer: Dictionary doesn't maintain a specific order for items,based on where they added.Dictionary are optimized for fast lookups based on keys,rather than maintaining order.Data retrival is more accessible and organised ,which can lead faster and more accurate data analysis and error free data.

# %% [markdown]
# Q20. Explain the difference between list and dictionary in torms of data retrival?
#
# Answer: In a list , data retrieval involves accessing elements by index ,which is straightforward but linear search time if the element position is unknown.In contrast,a dictionary allows access to data by key,offering faster retrieval regardless of element count.

# %% [markdown]
# Practical Questions Assignment 2

# %% [markdown]
# Q1. Write a code to create a string with your name and print it ?

# %%
name = "John Doe"

print(name)

# %% [markdown]
# Q2. Write a code to find the length of the string "Hello World" ?

# %%
text = "Hello World"

length = len(text)

print("The length of the string is:", length)

# %% [markdown]
# Q3. Write a code to slice the first 3 characters from the string "Python Programming" ?

# %%
text = "Python Programming"

sliced_text = text[:3]

print("The first 3 characters are:", sliced_text)

# %% [markdown]
# Q4. Write a code to convert the string "hello" to uppercase ?

# %%
text = "hello"

uppercase_text = text.upper()

print("The uppercase version is:", uppercase_text)

# %% [markdown]
# Q5. Write a code to replace the word "apple" with "orange" in the string "I like apple" ?

# %%
text = "I like apple"

modified_text = text.replace("apple", "orange")

print("The modified string is:", modified_text)

# %% [markdown]
# Q6. Write a code to create a list with numbers 1 to 5 and print it ?

# %%
numbers = [1, 2, 3, 4, 5]

print("The list is:", numbers)

# %% [markdown]
# Q7. Write a code to append the number 10 to the list [1, 2, 3, 4] ?

# %%
numbers = [1, 2, 3, 4]

numbers.append(10)

print("The modified list is:", numbers)

# %% [markdown]
# Q8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5] ?

# %%
numbers = [1, 2, 3, 4, 5]

numbers.remove(3)

print("The modified list is:", numbers)

# %% [markdown]
# Q9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'] ?

# %%
letters = ['a', 'b', 'c', 'd']

second_element = letters[1]

print("The second element is:", second_element)

# %% [markdown]
# Q10. Write a code to reverse the list [10, 20, 30, 40, 50] ?

# %%
numbers = [10, 20, 30, 40, 50]

numbers.reverse()

print("The reversed list is:", numbers)

# %% [markdown]
# Q11. Write a code to create a tuple with the elements 10, 20, 30 and print it ?

# %%
my_tuple = (10, 20, 30)

print("The tuple is:", my_tuple)

# %% [markdown]
# Q12.  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry') ?

# %%
fruits = ('apple', 'banana', 'cherry')

first_element = fruits[0]

print("The first element is:", first_element)

# %% [markdown]
# Q13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2) ?

# %%
my_tuple = (1, 2, 3, 2, 4, 2)

count_of_2 = my_tuple.count(2)

print("The number 2 appears", count_of_2, "times in the tuple.")

# %% [markdown]
# Q14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit') ?

# %%
my_tuple = ('dog', 'cat', 'rabbit')

index_of_cat = my_tuple.index('cat')

print("The index of 'cat' is:", index_of_cat)

# %% [markdown]
# Q15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana') ?

# %%
my_tuple = ('apple', 'orange', 'banana')

is_banana_in_tuple = 'banana' in my_tuple

print("Is 'banana' in the tuple?", is_banana_in_tuple)

# %% [markdown]
# Q16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it ?

# %%
my_set = {1, 2, 3, 4, 5}

print("The set is:", my_set)

# %% [markdown]
# Q17. Write a code to add the element 6 to the set {1, 2, 3, 4} ?

# %%
my_set = {1, 2, 3, 4}

my_set.add(6)

print("The updated set is:", my_set)

# %% [markdown]
# Q18. Write a code to create a tuple with the elements 10, 20, 30 and print it ?

# %%
my_tuple = (10, 20, 30)

print("The tuple is:", my_tuple)

# %% [markdown]
# Q19. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry') ?

# %%
my_tuple = ('apple', 'banana', 'cherry')

first_element = my_tuple[0]

print("The first element is:", first_element)

# %% [markdown]
# Q20.  Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2) ?

# %%
my_tuple = (1, 2, 3, 2, 4, 2)

count_of_2 = my_tuple.count(2)

print("The number 2 appears", count_of_2, "times in the tuple.")

# %% [markdown]
# Q21.  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit') ?

# %%
my_tuple = ('dog', 'cat', 'rabbit')

index_of_cat = my_tuple.index('cat')

print("The index of 'cat' is:", index_of_cat)

# %% [markdown]
# Q22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana') ?

# %%
my_tuple = ('apple', 'orange', 'banana')

is_banana_in_tuple = 'banana' in my_tuple

print("Is 'banana' in the tuple?", is_banana_in_tuple)

# %% [markdown]
# Q23.  Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it ?

# %%
my_set = {1, 2, 3, 4, 5}

print("The set is:", my_set)

# %% [markdown]
# Q24. Write a code to add the element 6 to the set {1, 2, 3, 4} ?

# %%
my_set = {1, 2, 3, 4}

my_set.add(6)

print("The updated set is:", my_set)

# %% [markdown]
#                                     ** THE END **
