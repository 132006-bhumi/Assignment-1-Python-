# %% [markdown]
# Theory Questions Assignment 3

# %% [markdown]
# Q1. What is the difference between a function and a method in Python?
#
# Answer: A function is a reusable block of code not tied to an object or class by default.A method that is associated with a class or instance and operates on that context.used with object oriented operation.Methods can be thought of as specialized functions that are tied to an object.

# %% [markdown]
# Q2. Explain the concept of function arguments and parameters in Python.
#
# Answer: In python parameters are defined in the function defination that's work as a place holder for the values that the will use.Parameters are local to the function scope.In python arguments are actual values or data passed to the function when it is called.

# %% [markdown]
# Q3. What are the different ways to define and call a function in Python?
#
# Answer:

# %% [markdown]
# Q4 What is the purpose of the return statement in a Python function?
#
# Answer: return statement is used in a function to send a result or value back to the caller after the function has executed. It is a way for a function to produce an output that can be used elsewhere in your program.Functions that return values can be reused in multiple parts of your code, avoiding repetition and keeping the code clean.

# %% [markdown]
# Q5 what are iterators in python and how do they differ from iterables?
#
# Answer: Iterables is any object in python that can return an iterator .Iterables are collections you can loop over.An iterator is essentially an object that keeps track of the current state of iteration and allows you to step through elements one at a time.

# %% [markdown]
# Q6 Explain concept of generator in python and how they are defined ?
#
# Answer: Generator is a function that yields value one by one using the yield keyword instead of returning all value using return Each time the generator’s next() method is called.Generators are a type of iterator, so they implement the iter() and next() methods, but unlike regular iterators, they are created using a function with yield.

# %% [markdown]
# Q7. what are the advantage of generator over regular fuction ?
#
# Answer: Generators produce values one at a time, only when needed. They don’t generate and store all values in memory at once, making them much more memory-efficient, especially when working with large datasets.generators only yield one item at a time, they consume very little memory even for large or infinite sequences.Regular functions return all values at once.which requires storing all the values in memory. This can quickly become problematic when the dataset is large.

# %% [markdown]
# Q8. what is lambda function in python and when typically used ?
#
# Answer: A lambda function in Python is a small, anonymous function that is defined using the lambda keyword. lambda function is a one-liner function that can have any number of input parameters but only one expression. The value of that expression is implicitly returned by the function.
#
# lambda arguments: expression where is lamda keyword is used to define the function ,arguments is input value , and expression is whose result is automatically return.

# %% [markdown]
# Q9. Explain the purpose and use of map function in python ?
#
# Answer: The map() function in Python is a built-in function that allows you to apply a given function to each item in an iterable (like a list, tuple, etc.) and return an iterator that produces the results. Essentially, it "maps" a function to every element of an iterable and yields the result of applying that function to each element.

# %% [markdown]
# Q10. what is difference between 'map()','reduce()'and 'filter()' functions in python?
#
# Answer: map() applies a given function to each item in an iterable (such as a list or tuple) and returns an iterator that yields the results.
#
# reduce() applies a binary function cumulatively to the items of an iterable, from left to right, so as to reduce the iterable to a single result.reduce() import form functools library.
#
# filter() applies a function to each item of an iterable and returns a filtered iterator containing only the items for which the function returns True.

# %% [markdown]
# Practical Questions Assignment 3

# %% [markdown]
# Q1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_of_even_numbers(numbers):

    return sum(num for num in numbers if num % 2 == 0)

numbers = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(numbers)
print("Sum of even numbers:", result)

# %% [markdown]
# Q2.  Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):

    return s[::-1]

input_string = "Hello, World!"
reversed_string = reverse_string(input_string)
print("Reversed string:", reversed_string)

# %% [markdown]
# Q3.  Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_numbers(numbers):

    return [num ** 2 for num in numbers]

input_list = [1, 2, 3, 4, 5]
squared_list = square_numbers(input_list)
print("Squared numbers:", squared_list)

# %% [markdown]
# Q4. Write a Python function that checks if a given number is prime or not from 1 to 200 ?

# %%
def is_prime(number):

    if number < 2:
        return False

    for i in range(2, int(number**0.5) + 1):
        if number % i == 0:
            return False

    return True

for num in range(1, 201):
    if is_prime(num):
        print(num, "is a prime number.")

# %% [markdown]
# Q5.Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class FibonacciIterator:
    def __init__(self, terms):
        self.terms = terms
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.terms:

            fib_number = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return fib_number
        else:
            raise StopIteration

fibonacci = FibonacciIterator(10)
for num in fibonacci:
    print(num)

# %% [markdown]
# Q6. Write a generator function in Python that yields the powers of 2 up to a given exponent ?

# %%
def powers_of_two(exponent):

    for i in range(exponent + 1):
        yield 2 ** i

for power in powers_of_two(5):
    print(power)

# %% [markdown]
# Q7. Implement a generator function that reads a file line by line and yields each line as a string ?

# %% [markdown]
# Q8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple ?

# %%
tuples_list = [(1, 3), (2, 1), (4, 2), (5, 0)]

sorted_list = sorted(tuples_list, key=lambda x: x[1])

print(sorted_list)

# %% [markdown]
# Q9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit ?

# %%
celsius_temperatures = [0, 20, 30, 40, 100]

def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

print(fahrenheit_temperatures)

# %% [markdown]
# Q10. Create a Python program that uses `filter()` to remove all the vowels from a given string ?

# %%
def remove_vowels(char):
    vowels = 'aeiouAEIOU'
    return char not in vowels

input_string = "Hello, World!"

filtered_string = ''.join(filter(remove_vowels, input_string))

print(filtered_string)

# %% [markdown]
# Q11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99],
]

result = list(map(
    lambda order: (order[0], order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)),
    orders
))

print(result)

# %% [markdown]
#                            **  THE END **
